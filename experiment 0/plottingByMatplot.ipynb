# %%
import matplotlib

# %%
print(matplotlib.__version__)
# Out:
# 3.10.3

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([1,2,3,4]) 
y=np.array([10,30,20,40])

plt.plot(x,y)
plt.show()
